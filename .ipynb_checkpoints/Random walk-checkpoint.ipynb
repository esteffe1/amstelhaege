# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import style
style.use('Solarize_Light2')

import random
from math import sqrt

import plotah
import calc
import hage

GRID_X = 18
GRID_Y = 16

ah = hage.amstel("viertel_eins.json")

print( "  Name of area:     ", ah.name)
print( "  Total houses:     ", ah.total)
print( "  Eensgezinswoning: ", ah.total * ah.ewg)
print( "  Bungalow:         ", ah.total * ah.bgl)
print( "  Maison:           ", ah.total * ah.msn)
print("")

# Create composition of houses
ewg_number = int(ah.total * ah.ewg)
bgl_number = int(ah.total * ah.bgl)
msn_number = int(ah.total * ah.msn)

# Get specifications for eash building
for building in ah.buildings:
    print("  Building: ", building.name) 
    print("  Length:   ", building.length, "  Width: ", building.width)
    print("  Extra:    ", building.extra,  "  Bonus: ", building.bonus)
    print("")
    
buildings = {}
n = 0
for i in range(0, int(ewg_number)):
    buildings[i] = {'type' : 'egw', 'n' : n, 'x' : 0, 'y' : 0, 'extra' : 2.0, 'length' : 8.0 , 'width' : 8.0, 'offset' : 0.0} 
    n += 1

spot = i+1
n = 0
for i in range(spot, spot + int(bgl_number)):
    buildings[i] = {'type' : 'bgl', 'n' : n,'x' : 0, 'y' : 0, 'extra' : 3.0, 'length' : 7.5 , 'width' : 10.0, 'offset' : 30.0}  
    n += 1

n = 0
spot = i+1    
for i in range(spot, spot + int(msn_number)):
    buildings[i] = {'type' : 'msn', 'n' : n,'x' : 0, 'y' : 0, 'extra' : 6.0, 'length' : 10.5 ,'width' : 11.0, 'offset' : 60.0} 
    n += 1
    
print("")

score_total = []

for run in range(0,1000):
    # Generate random grid posistion
    grid = []
    for y in range(0, 10):
        for x in range (0,10):
            grid.append([x,y])
    random.shuffle(grid)    

    # Calculate distances between all buildings
    dist_table = calc.calc_distance_table( ah, grid )
    # Find neighbours
    min_distance = calc.calc_min_distance( ah, dist_table)

    # Assign each building a grid posisttion  
    for spot in range(0, ah.total):  
        buildings[spot]['x']  = grid[spot][0] * GRID_X
        buildings[spot]['y']  = grid[spot][1] * GRID_Y

    # Calculate value of Amstelhaege
    score_total.append( calc.calc_score(ah, buildings, min_distance ) )    

# Plot the histogram of all scores   
plotah.plot_histogram(score_total)

# Plot the layout of Amstelheage
plotah.ah_plot( ah, buildings, min_distance )
# Out:
#   Name of area:      Amstelhaege
#   Total houses:      20
#   Eensgezinswoning:  12.0
#   Bungalow:          5.0
#   Maison:            3.0
#
#   Building:  Eens gezins woming
#   Length:    8.0   Width:  8.0
#   Extra:     2.0   Bonus:  3.0
#
#   Building:  Bungalow
#   Length:    7.5   Width:  10
#   Extra:     3.0   Bonus:  4.0
#
#   Building:  Maison
#   Length:    10.5   Width:  11.0
#   Extra:     6.0   Bonus:  6.0
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a08e2fd7783f> in <module>
#      83
#      84 # Plot the layout of Amstelheage
# ---> 85 plotah.ah_plot( ah, buildings, min_distance )
#      86
#
# ~\esteffe1\Projects\Heuristieken\Amstelheage\plotah.py in ah_plot(ah, buildings, min_distance)
#      63        # Set the begin and end point
#      64        ax1.plot(x,  y, 'ro')
# ---> 65        ax1.plot(xn, yn , 'gr')
#      66
#      67        # Neighbour top right
#
# c:\users\edwin\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\users\edwin\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1601         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1602
# -> 1603         for line in self._get_lines(*args, **kwargs):
#    1604             self.add_line(line)
#    1605             lines.append(line)
#
# c:\users\edwin\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# c:\users\edwin\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     340         ret = []
#     341         if len(tup) > 1 and isinstance(tup[-1], str):
# --> 342             linestyle, marker, color = _process_plot_format(tup[-1])
#     343             tup = tup[:-1]
#     344         elif len(tup) == 3:
#
# c:\users\edwin\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_base.py in _process_plot_format(fmt)
#     108             if color is not None:
#     109                 raise ValueError(
# --> 110                     'Illegal format string "%s"; two color symbols' % fmt)
#     111             color = c
#     112         elif c == 'C' and i < len(chars) - 1:
#
# ValueError: Illegal format string "gr"; two color symbols
