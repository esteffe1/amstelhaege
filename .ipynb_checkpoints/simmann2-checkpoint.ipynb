# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import style
style.use('Solarize_Light2')
from math import sqrt
import random
import copy

# Project source files
import plotah
import calc
import hill
import hage

GRID_X = 18
GRID_Y = 16

GRID_X_POINTS = 10
GRID_Y_POINTS = 10

iterations = 500000

ah = hage.amstel("viertel_eins.json")

print( "  Name of area:     ", ah.name)
print( "  Total houses:     ", ah.total)
print( "  Eensgezinswoning: ", ah.total * ah.ewg)
print( "  Bungalow:         ", ah.total * ah.bgl)
print( "  Maison:           ", ah.total * ah.msn)
print("")

# Create composition of houses
ewg_number = int(ah.total * ah.ewg)
bgl_number = int(ah.total * ah.bgl)
msn_number = int(ah.total * ah.msn)

# Get specifications for eash building
for building in ah.buildings:
    print("  Building: ", building.name) 
    print("  Length:   ", building.length, "  Width: ", building.width)
    print("  Extra:    ", building.extra,  "  Bonus: ", building.bonus)
    print("")
    
buildings = {}
n = 0
for i in range(0, int(ewg_number)):
    buildings[i] = {'type' : 'egw', 'value' : 285, 'n' : n, 'x' : 0, 'y' : 0, 'extra' : 2.0, 'length' : 8.0 , 'width' : 8.0, 'bonus' : 0.03} 
    n += 1

spot = i+1
n = 0
for i in range(spot, spot + int(bgl_number)):
    buildings[i] = {'type' : 'bgl', 'value' : 399,'n' : n,'x' : 0, 'y' : 0, 'extra' : 3.0, 'length' : 7.5 , 'width' : 10.0, 'bonus' : 0.04}  
    n += 1

n = 0
spot = i+1    
for i in range(spot, spot + int(msn_number)):
    buildings[i] = {'type' : 'msn', 'value' : 610, 'n' : n,'x' : 0, 'y' : 0, 'extra' : 6.0, 'length' : 10.5 ,'width' : 11.0, 'bonus' : 0.06} 
    n += 1
    
print("")

hill.hillclimber(ah, buildings, iterations)
# Out:
#   Name of area:      Amstelhaege
#   Total houses:      20
#   Eensgezinswoning:  12.0
#   Bungalow:          5.0
#   Maison:            3.0
#
#   Building:  Eens gezins woming
#   Length:    8.0   Width:  8.0
#   Extra:     2.0   Bonus:  3.0
#
#   Building:  Bungalow
#   Length:    7.5   Width:  10
#   Extra:     3.0   Bonus:  4.0
#
#   Building:  Maison
#   Length:    10.5   Width:  11.0
#   Extra:     6.0   Bonus:  6.0
#
#
#   Run:  Iteration:  0 Cuurent top yield:  10611.311593398075
#  alive at:  0
#   Run:  Iteration:  1 Cuurent top yield:  10745.617078909576
#   Run:  Iteration:  2 Cuurent top yield:  10909.012330344687
#   Run:  Iteration:  4 Cuurent top yield:  11156.1495644273
#   Run:  Iteration:  34 Cuurent top yield:  11282.992455496562
#   Run:  Iteration:  63 Cuurent top yield:  11796.692884634702
#   Run:  Iteration:  71 Cuurent top yield:  12056.900189326832
#   Run:  Iteration:  101 Cuurent top yield:  12490.682248166526
#   Run:  Iteration:  426 Cuurent top yield:  12602.182075102071
#   Run:  Iteration:  977 Cuurent top yield:  13035.63050892542
#   Run:  Iteration:  1862 Cuurent top yield:  13227.22294802983
#   Run:  Iteration:  6488 Cuurent top yield:  13518.58720529476
#   Run:  Iteration:  6496 Cuurent top yield:  13600.587831410086
#   Run:  Iteration:  8361 Cuurent top yield:  14030.593587316072
#  alive at:  10000
#  alive at:  20000
#  alive at:  30000
#  alive at:  40000
#  alive at:  50000
#   Run:  Iteration:  57290 Cuurent top yield:  14053.55551412926
#  alive at:  60000
#   Run:  Iteration:  61092 Cuurent top yield:  14399.435598007281
#  alive at:  70000
#  alive at:  80000
#  alive at:  90000
#  alive at:  100000
#  alive at:  110000
#  alive at:  120000
#  alive at:  130000
#  alive at:  140000
#  alive at:  150000
#  alive at:  160000
#  alive at:  170000
#  alive at:  180000
#  alive at:  190000
#  alive at:  200000
#  alive at:  210000
#  alive at:  220000
#  alive at:  230000
#  alive at:  240000
#  alive at:  250000
#  alive at:  260000
#  alive at:  270000
#  alive at:  280000
#  alive at:  290000
#  alive at:  300000
#  alive at:  310000
#  alive at:  320000
#  alive at:  330000
#  alive at:  340000
#  alive at:  350000
#  alive at:  360000
#  alive at:  370000
#  alive at:  380000
#  alive at:  390000
#  alive at:  400000
#  alive at:  410000
#  alive at:  420000
#  alive at:  430000
#  alive at:  440000
#  alive at:  450000
#  alive at:  460000
#  alive at:  470000
#  alive at:  480000
#  alive at:  490000
#   Run:  Iteration:  495370 Cuurent top yield:  14564.845110738019
